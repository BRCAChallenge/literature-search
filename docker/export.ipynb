# %% [markdown]
# # Export
# Explorations using the intermediate files in correlate.py for various export formats

# %%
import os
import json
import sqlite3
import pandas as pd

os.chdir(os.path.expanduser("~/data/pubmunch/crawl/"))

# %%
connection = sqlite3.connect("file:text/articles.db?mode=ro", uri=True)
articles = pd.read_sql_query("SELECT * FROM articles", connection)
print("{} articles downloaded with BRCA in the title or abstract".format(articles.shape[0]))
articles.pmid = articles.pmid.astype(str)
articles.head()
# Out:
# 14044 articles downloaded with BRCA in the title or abstract
#     articleId    externalId source publisher origFile  \
# 0  5011585672  PMID11585672         download
# 1  5019688261  PMID19688261         download
# 2  5012228710  PMID12228710         download
# 3  5029369605  PMID29369605         download
# 4  5022084640  PMID22084640         download
#
#                                     journal  printIssn      eIssn  \
# 0                  Trends in genetics : TIG  0168-9525  0168-9525
# 1      Breast cancer research and treatment  0167-6806  1573-7217
# 2                  Science (New York, N.Y.)  0036-8075  1095-9203
# 3                                  Genetika  0016-6758  0016-6758
# 4  Therapeutic advances in medical oncology  1758-8340  1758-8359
#
#   journalUniqueId  year   ...    issue  page      pmid    pmcId  \
# 0         8507085  2001   ...       10   S18  11585672
# 1         8111104  2010   ...        3   575  19688261
# 2         0404511  2002   ...     5588  1837  12228710
# 3         0047354  2016   ...       10  1215  29369605
# 4       101510808  2011   ...        6   257  22084640  3210467
#
#                              doi  \
# 0  10.1016/s0168-9525(01)02451-9
# 1      10.1007/s10549-009-0501-3
# 2  10.1126/science.297.5588.1837
# 3      10.1134/s102279541609012x
# 4       10.1177/1758834011417039
#
#                                          fulltextUrl  \
# 0  https://linkinghub.elsevier.com/retrieve/pii/S...
# 1
# 2
# 3  https://link.springer.com/article/10.1134%2FS1...
# 4
#
#                        time      offset    size  chunkId
# 0  2018-11-14T16:29:09+0000          78    5258  0_00000
# 1  2018-11-14T16:29:16+0000        5048  100825  0_00000
# 2  2018-11-14T16:29:40+0000  1436851129  148950  0_00000
# 3  2018-11-14T16:30:43+0000  4458079378   22264  0_00000
# 4  2018-11-14T16:30:58+0000  6079002966   93229  0_00000
#
# [5 rows x 30 columns]

# %%
variants = pd.read_table("variants-normalized.tsv", index_col="norm_g_hgvs")
print("{} variants in BRCA Exchange database".format(variants.shape[0]))
variants.head()
# Out:
# 20934 variants in BRCA Exchange database
#                             Chr       Pos Ref Alt  \
# norm_g_hgvs
# NC_000013.11:g.32314943A>G   13  32314943   A   G
# NC_000013.11:g.32315226G>A   13  32315226   G   A
# NC_000013.11:g.32315490C>T   13  32315490   C   T
# NC_000013.11:g.32315519C>T   13  32315519   C   T
# NC_000013.11:g.32315532C>T   13  32315532   C   T
#
#                            pyhgvs_Genomic_Coordinate_38            pyhgvs_cDNA
# norm_g_hgvs
# NC_000013.11:g.32314943A>G         chr13:g.32314943:A>G  NM_000059.3:c.-764A>G
# NC_000013.11:g.32315226G>A         chr13:g.32315226:G>A  NM_000059.3:c.-481G>A
# NC_000013.11:g.32315490C>T         chr13:g.32315490:C>T  NM_000059.3:c.-217C>T
# NC_000013.11:g.32315519C>T         chr13:g.32315519:C>T  NM_000059.3:c.-188C>T
# NC_000013.11:g.32315532C>T         chr13:g.32315532:C>T  NM_000059.3:c.-175C>T

# %%
# mentions = pd.read_table("mentions-normalized.tsv", index_col="norm_g_hgvs").drop_duplicates(["pmid", "snippet"])
mentions = pd.read_table("mentions-normalized.tsv", index_col="norm_g_hgvs")
mentions.pmid = mentions.pmid.astype(str)
print("{} total mentions found".format(mentions.shape[0]))
mentions.head()
# Out:
# 442198 total mentions found
#                                       norm_c_hgvs      pmid  \
# norm_g_hgvs
# NC_000007.14:g.96709760A>C     NM_006304.1:c.4T>G  12228710
# NC_000004.12:g.56655997A>C  NM_001145459.1:c.4T>G  12228710
# NC_000004.12:g.56655997A>C     NM_139212.3:c.4T>G  12228710
# NC_000004.12:g.56655997A>C     NM_139211.4:c.4T>G  12228710
# NC_000007.14:g.96709760A>C     NM_006304.1:c.4T>G  12228710
#
#                                                                       snippet
# norm_g_hgvs
# NC_000007.14:g.96709760A>C  ee-stranded β sheet with OB2β1 and OB2β2, as w...
# NC_000004.12:g.56655997A>C  ee-stranded β sheet with OB2β1 and OB2β2, as w...
# NC_000004.12:g.56655997A>C  ee-stranded β sheet with OB2β1 and OB2β2, as w...
# NC_000004.12:g.56655997A>C  ee-stranded β sheet with OB2β1 and OB2β2, as w...
# NC_000007.14:g.96709760A>C  ee-stranded ␤ sheet with OB2␤1 and OB2␤2, as w...

# %%
# Prune mentions down to only those correlated to a variant in BRCA Excchange
variant_mentions = pd.merge(variants, mentions, left_index=True, right_index=True)
print("{} mentions of variants in BRCA Exchange".format(variant_mentions.shape[0]))
variant_mentions.head()
# Out:
# 55657 mentions of variants in BRCA Exchange
#                             Chr       Pos Ref Alt  \
# norm_g_hgvs
# NC_000013.11:g.32316461A>G   13  32316461   A   G
# NC_000013.11:g.32316461A>G   13  32316461   A   G
# NC_000013.11:g.32316461A>G   13  32316461   A   G
# NC_000013.11:g.32316461A>G   13  32316461   A   G
# NC_000013.11:g.32316461A>G   13  32316461   A   G
#
#                            pyhgvs_Genomic_Coordinate_38         pyhgvs_cDNA  \
# norm_g_hgvs
# NC_000013.11:g.32316461A>G         chr13:g.32316461:A>G  NM_000059.3:c.1A>G
# NC_000013.11:g.32316461A>G         chr13:g.32316461:A>G  NM_000059.3:c.1A>G
# NC_000013.11:g.32316461A>G         chr13:g.32316461:A>G  NM_000059.3:c.1A>G
# NC_000013.11:g.32316461A>G         chr13:g.32316461:A>G  NM_000059.3:c.1A>G
# NC_000013.11:g.32316461A>G         chr13:g.32316461:A>G  NM_000059.3:c.1A>G
#
#                                    norm_c_hgvs      pmid  \
# norm_g_hgvs
# NC_000013.11:g.32316461A>G  NM_000059.3:c.1A>G  30103829
# NC_000013.11:g.32316461A>G  NM_000059.3:c.1A>G  30103829
# NC_000013.11:g.32316461A>G  NM_000059.3:c.1A>G  30103829
# NC_000013.11:g.32316461A>G  NM_000059.3:c.1A>G  30103829
# NC_000013.11:g.32316461A>G  NM_000059.3:c.1A>G  22006311
#
#                                                                       snippet
# norm_g_hgvs
# NC_000013.11:g.32316461A>G  tions: in EPCAM, c.412C>T p.(Arg138*), and coe...
# NC_000013.11:g.32316461A>G  EPCAM, c.412C>T p.(Arg138*), and coexisting mu...
# NC_000013.11:g.32316461A>G  tions: in EPCAM, c.412C>T p.(Arg138*), and coe...
# NC_000013.11:g.32316461A>G  EPCAM, c.412C>T p.(Arg138*), and coexisting mu...
# NC_000013.11:g.32316461A>G  nd in-frame deletions were classified as delet...

# %%
# Some of the snippets are multiple mentiones separated by | so unpack these,
# but limit to 5 as some have as many as 168!
print("Unpacking {} of {} snippets with multiple phrases seaparated by '|'".format(
    variant_mentions[variant_mentions.snippet.str.contains("\|")].shape[0], variant_mentions.shape[0]))
# Out:
# Unpacking 18909 of 55657 snippets with multiple phrases seaparated by '|'

# %%
# https://stackoverflow.com/questions/17116814/pandas-how-do-i-split-text-in-a-column-into-multiple-rows/21032532

# Resest index so each row id is unique vs. norm_g_hgvs
df = variant_mentions.reset_index()
# df = variant_mentions[variant_mentions.snippet.str.contains("\|")].iloc[0:100].reset_index()

# Generate a new dataframe splitting each snippet segment into its own row
# Limit to max of 3 as some of them have > 100
snippets = df.apply(lambda x: pd.Series(x.snippet.split("|")[:3]), axis=1).stack()

# To line up with the original index
snippets.index = snippets.index.droplevel(-1)

# Join back to the original dataframe replaceing the old "snippet" columnd
snippets.name = "snippet"
del df["snippet"]
exploded = df.join(snippets).drop_duplicates(["pyhgvs_Genomic_Coordinate_38", "snippet"]).set_index("pyhgvs_Genomic_Coordinate_38")
print("{} after expanding and de-duplicating snippets".format(exploded.shape[0]))
# Out:
# 48941 after expanding and de-duplicating snippets

# %%
exploded.head()
# Out:
#                                              norm_g_hgvs  Chr       Pos Ref  \
# pyhgvs_Genomic_Coordinate_38
# chr13:g.32316461:A>G          NC_000013.11:g.32316461A>G   13  32316461   A
# chr13:g.32316461:A>G          NC_000013.11:g.32316461A>G   13  32316461   A
# chr13:g.32316461:A>G          NC_000013.11:g.32316461A>G   13  32316461   A
# chr13:g.32316461:A>G          NC_000013.11:g.32316461A>G   13  32316461   A
# chr13:g.32316461:A>G          NC_000013.11:g.32316461A>G   13  32316461   A
#
#                              Alt         pyhgvs_cDNA         norm_c_hgvs  \
# pyhgvs_Genomic_Coordinate_38
# chr13:g.32316461:A>G           G  NM_000059.3:c.1A>G  NM_000059.3:c.1A>G
# chr13:g.32316461:A>G           G  NM_000059.3:c.1A>G  NM_000059.3:c.1A>G
# chr13:g.32316461:A>G           G  NM_000059.3:c.1A>G  NM_000059.3:c.1A>G
# chr13:g.32316461:A>G           G  NM_000059.3:c.1A>G  NM_000059.3:c.1A>G
# chr13:g.32316461:A>G           G  NM_000059.3:c.1A>G  NM_000059.3:c.1A>G
#
#                                   pmid  \
# pyhgvs_Genomic_Coordinate_38
# chr13:g.32316461:A>G          30103829
# chr13:g.32316461:A>G          30103829
# chr13:g.32316461:A>G          30103829
# chr13:g.32316461:A>G          22006311
# chr13:g.32316461:A>G          22006311
#
#                                                                         snippet
# pyhgvs_Genomic_Coordinate_38
# chr13:g.32316461:A>G          tions: in EPCAM, c.412C>T p.(Arg138*), and coe...
# chr13:g.32316461:A>G          EPCAM, c.412C>T p.(Arg138*), and coexisting mu...
# chr13:g.32316461:A>G          in EPCAM, c.412C>T p.(Arg138*), and coexisting...
# chr13:g.32316461:A>G          nd in-frame deletions were classified as delet...
# chr13:g.32316461:A>G          BRCA1 p.M1I,<<< p.M1V>>>, and p.C61G and TP53 ...

# %%
# # Variants by pyhgvs_Genomic_Coordinate_38 as array of mentions
# variant_mentions_dict = {
#     k: v.to_dict(orient="records")
#     for k, v in variant_mentions.reset_index(level=0)
#                 .set_index("pyhgvs_Genomic_Coordinate_38")
#                 .groupby(["pyhgvs_Genomic_Coordinate_38"])}

# %% [markdown]
# #### Variants by pyhgvs_Genomic_Coordinate_38 by pmid with all snippets in a list

# %%
combined = exploded.groupby(["pyhgvs_Genomic_Coordinate_38", "pmid"])["snippet"].apply(lambda s: s.tolist())

# %%
combined["chr13:g.32316470:G>T"]
# Out:
# pmid
# 17453335    [Two novel BRCA2 germline mutations <<<(G4X>>>...
# 24010542    [_5797delTA  11B  c.4409_4410delTA c.4415_4418...
# 24312913    [G, 461delTC [41]  4817A>G, 8477delAGA [41]  —...
# 27225819    [  95.96%   3.239   447.681   98.46%   BRCA2+ ...
# 28751759    [65Leu) VUS, which was also present in this sa...
# Name: snippet, dtype: object

# %%
literature = {
    "papers": articles[articles.pmid.isin(variant_mentions.pmid)].set_index("pmid", drop=False).to_dict(orient="index"),
    "variants": {
        k: {kk: vv[0] for kk, vv in v.unstack().transpose().iterrows()}
        for k, v in combined.groupby("pyhgvs_Genomic_Coordinate_38")},
}
with open("literature-05-12-2018-v1.json", "w") as output:
    output.write(json.dumps(literature))
    
literature["variants"]["chr13:g.32316470:G>T"]
# Out:
# {'17453335': ['Two novel BRCA2 germline mutations <<<(G4X>>> and 3783del10) are reported here for the first time.',
#   'Each of the five BRCA2 mutations is observed only once; three are frameshift (3783del10, 4637delTA, 5950delCT), one is nonsense <<<(G4X>>>), and one is a single base substitution that results in aberrant splicing (7235G\xa0>\xa0A, skipping of exons 12–13) [15].',
#   'h.gov/ Intramural_research/Lab_transfer/Bic/Member/ BRCA1_mutation_database.html). The two novel BRCA2 mutations described here for the first time are<<< G4X>>> and 3783del10, located in exons 2 and 11, respectively.',
#   'Each of the five BRCA2 mutations is observed only once; three are frameshift (3783del10, 4637delTA, 5950delCT), one is nonsense <<<(G4X>>>), and one is a single base substitution that results in aberrant splicing (7235G > A, skipping of exons 12–13) [15].',
#   'The two novel BRCA2 mutations described here for the first time are<<< G4X>>> and 3783del10, located in exons 2 and 11, respectively.'],
#  '24010542': ['_5797delTA  11B  c.4409_4410delTA c.4415_4418delAGAA c.4767delA  11A  10  c.3555_3564del10 c.3919delG  9  p.Ser780X  7  c.2808_2811delAAAC c.2830delA <<< p.Gly4X>>>  5  21 23 20 22  8  c.1796_1800del5  3  1  6  c.658_659delGT  4  2  Fig. 1.'],
#  '24312913': ['G, 461delTC [41]  4817A>G, 8477delAGA [41]  —   Greek (South eastern Europe)  5382insC and G1738R   [92]   G5331A, 3819delGTAAA [180]   8984delG [35],<<< G4X>>> and 3783del10 [92]  5382insC and G1738R   [92], 3782del10, 4512insT [180]   Slovenia  c.1193C>A [86]   c.181T>G, c.1687C>T, 5382insC,   c.844_850dupT',
#   '8142del5 [28], exons 5–14 del Exons 1–17 del 5382insC [175]  c.6589delA [178, 179]  c.6589delA [178, 179]  4817A>G, 8477delAGA [41]  —  8984delG [35],<<< G4X>>> and 3783del10 [92]  5382insC and G1738R [92], 3782del10, 4512insT [180]  c.5101C>T, c.5433 5436delGGAA [86] c.7806−2A>G, c.5291C>G, c.3975 3978dupTGC'],
#  '27225819': ['  95.96%   3.239   447.681   98.46%   BRCA2+   c.1447_1450ins4; p.Ala483AlaValfs   Path   #CQ3 TS   377.2   42.18%   227   120.384   57.25%   BRCA2+  <<< c.10G>T>>>; p.Gly4Ter   Path   #CQ5 TS   811.4   66.65%   400   173.040   89.41%   BRCA2+   c.5909C>A; p.Ser1970Ter   Path   #CQ7 TS   319.23   74.47%   105   3',
#   '  3.239   447.681   98.46%   BRCA2+   c.1447_1450ins4; p.Ala483AlaValfs   Path   #CQ3 TS   377.2   42.18%   227   120.384   57.25%   BRCA2+   c.10G>T;<<< p.Gly4Ter>>>   Path   #CQ5 TS   811.4   66.65%   400   173.040   89.41%   BRCA2+   c.5909C>A; p.Ser1970Ter   Path   #CQ7 TS   319.23   74.47%   105   32.248   10.',
#   'lT; p.Phe829Leufs c.1175_1214del40; p.Leu392Glnfs c.3756_3759delGTCT; p.Ser1253Argfs c.8764_8764delA; p.Ser2922Valfs c.1447_1450ins4; p.Ala483AlaValfs<<< c.10G>T>>>; p.Gly4Ter c.5909C>A; p.Ser1970Ter c.7617 1 1G>T c.6059_6062del4; p.Glu2020Valfs c.7251_7252delCA; p.His2417Glnfs c.9676delT; p.Tyr3226Ilefs c.4183C>T; p.Gln1395Ter c.5095C>T; p.Arg1699Trp  TABLE 3.',
#   '829Leufs c.1175_1214del40; p.Leu392Glnfs c.3756_3759delGTCT; p.Ser1253Argfs c.8764_8764delA; p.Ser2922Valfs c.1447_1450ins4; p.Ala483AlaValfs c.10G>T;<<< p.Gly4Ter>>> c.5909C>A; p.Ser1970Ter c.7617 1 1G>T c.6059_6062del4; p.Glu2020Valfs c.7251_7252delCA; p.His2417Glnfs c.9676delT; p.Tyr3226Ilefs c.4183C>T; p.Gln1395Ter c.5095C>T; p.Arg1699Trp  TABLE 3.'],
#  '28751759': ['65Leu) VUS, which was also present in this sample.  Laboratory 16, using an HRM pre-screening strategy, failed to identify the BRCA2 nonsense mutation<<< c.10G>T>>>; p.(Gly4*) in one sample.',
#   '2Glnfs*5) NA 40 bp deletion (frameshift) 2 BRCA1 (NM_007294.3); BRCA2 (NM_000059.3) NA NA Control sample–no pathogenic mutations 3 BRCA2 (NM_000059.3)<<< c.10G4T>>>; p.(Gly4*) NA Point mutation (nonsense) 4 BRCA1 (NM_007294.3) c.442-?_547þ ?del, NA LGR: deletion (exon 8) 5 BRCA2 (NM_000059.3) c.5909C4A; p.(Ser197',
#   '465Leu) VUS, which was also present in this sample. Laboratory 16, using an HRM pre-screening strategy, failed to identify the BRCA2 nonsense mutation<<< c.10G4T>>>; p.(Gly4*) in one sample.']}
